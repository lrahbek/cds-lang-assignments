# %% [markdown]
# ## Evaluating Environmental Impact of Exam Portfolio

# %% [markdown]
# ### Import Packages
# Dependencies are described in the README.md file

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import glob
from scipy.stats import zscore
import seaborn.objects as so

# %% [markdown]
# ### Load in Emissions Data
# The data is located in the ```out``` folder, and each of the .csv files ending with a run-id are loaded in to investigate the impact of the different tasks in each assignment. The individual .csv files are loaded into one dataframe, with columns containing the following information:
# - task_name: The manually specified name of the task
# - project_name: The manually specified name of the assignment in which the task was performed
# - duration: The time the task took to run, in seconds
# - emisions: The approximate emisions from this task, in CO₂-equivalents, in kg.
# - emissions_rate: The emissions per second (kg/s)
#
# As the data is extracted per task, a second dataframe will be created with the totals for each assignment.

# %%
emissions = pd.DataFrame()
for file in sorted(glob.glob(os.path.join("../out/", "emissions_*"))):
    emissions = pd.concat([emissions, pd.read_csv(file, usecols=[0,2,4,5,6])])
emissions = emissions.sort_values(by= "project_name").reset_index(drop=True)
emissions
# Out:
#                      task_name  project_name     duration     emissions  \
# 0           Feature extraction  Assignment-1   187.111034  1.722601e-03
# 1             Load spacy model  Assignment-1     1.346084  1.240391e-05
# 2         Visualising features  Assignment-1     7.817864  7.197657e-05
# 3   Load vectorised data (MLP)  Assignment-2     0.013223  1.350464e-07
# 4    Load vectorised data (LR)  Assignment-2     0.010718  1.060970e-07
# 5               Vectorize data  Assignment-2    11.030644  1.014808e-04
# 6            Define vectorizer  Assignment-2     0.004021  3.588011e-08
# 7                    Load data  Assignment-2     0.377494  3.493013e-06
# 8            Evaluate LR model  Assignment-2     0.047111  4.300415e-07
# 9                 Fit LR model  Assignment-2     0.066405  6.069169e-07
# 10   Load vectorised data (LR)  Assignment-2     0.011984  1.202486e-07
# 11        Fit LR model with GS  Assignment-2   158.351154  1.457815e-03
# 12           Plot MLP training  Assignment-2     0.182935  1.679132e-06
# 13          Evaluate MLP model  Assignment-2     0.310191  2.854203e-06
# 14               Fit MLP model  Assignment-2    30.486400  2.800561e-04
# 15  Load vectorised data (MLP)  Assignment-2     0.012283  1.290098e-07
# 16           Plot MLP training  Assignment-2     0.214482  1.970570e-06
# 17          Evaluate MLP model  Assignment-2     0.211549  1.954439e-06
# 18       Fit MLP model with GS  Assignment-2  2271.886904  2.091495e-02
# 19           Evaluate LR model  Assignment-2     0.041986  3.853061e-07
# 20   Load model and find words  Assignment-3    12.653821  1.164590e-04
# 21                 Find artist  Assignment-3     0.681304  6.283050e-06
# 22               Keyword query  Assignment-3     0.014269  1.311332e-07
# 23                  Load model  Assignment-4    21.219158  1.953576e-04
# 24                   Load data  Assignment-4     0.250360  2.298704e-06
# 25      Emotion classification  Assignment-4  5182.650649  4.771336e-02
# 26                Reshape data  Assignment-4     0.069852  6.388758e-07
# 27               Plot emotions  Assignment-4     3.841459  3.535423e-05
#
#     emissions_rate
# 0         0.000009
# 1         0.000009
# 2         0.000009
# 3         0.000009
# 4         0.000009
# 5         0.000009
# 6         0.000009
# 7         0.000009
# 8         0.000009
# 9         0.000009
# 10        0.000009
# 11        0.000009
# 12        0.000009
# 13        0.000009
# 14        0.000009
# 15        0.000009
# 16        0.000009
# 17        0.000009
# 18        0.000009
# 19        0.000009
# 20        0.000009
# 21        0.000009
# 22        0.000009
# 23        0.000009
# 24        0.000009
# 25        0.000009
# 26        0.000009
# 27        0.000009

# %%
emissions_total = emissions[["project_name", "duration", "emissions"]].groupby(["project_name"]).sum().reset_index()
(emissions_total["emissions"] / emissions_total["duration"])*100
emissions_total
# Out:
#    project_name     duration  emissions
# 0  Assignment-1   196.274982   0.001807
# 1  Assignment-2  2473.259483   0.022768
# 2  Assignment-3    13.349394   0.000123
# 3  Assignment-4  5208.031479   0.047947

# %%
emissions.loc[emissions["project_name"] == "Assignment-2"]
# Out:
#                      task_name  project_name     duration     emissions  \
# 3   Load vectorised data (MLP)  Assignment-2     0.013223  1.350464e-07
# 4    Load vectorised data (LR)  Assignment-2     0.010718  1.060970e-07
# 5               Vectorize data  Assignment-2    11.030644  1.014808e-04
# 6            Define vectorizer  Assignment-2     0.004021  3.588011e-08
# 7                    Load data  Assignment-2     0.377494  3.493013e-06
# 8            Evaluate LR model  Assignment-2     0.047111  4.300415e-07
# 9                 Fit LR model  Assignment-2     0.066405  6.069169e-07
# 10   Load vectorised data (LR)  Assignment-2     0.011984  1.202486e-07
# 11        Fit LR model with GS  Assignment-2   158.351154  1.457815e-03
# 12           Plot MLP training  Assignment-2     0.182935  1.679132e-06
# 13          Evaluate MLP model  Assignment-2     0.310191  2.854203e-06
# 14               Fit MLP model  Assignment-2    30.486400  2.800561e-04
# 15  Load vectorised data (MLP)  Assignment-2     0.012283  1.290098e-07
# 16           Plot MLP training  Assignment-2     0.214482  1.970570e-06
# 17          Evaluate MLP model  Assignment-2     0.211549  1.954439e-06
# 18       Fit MLP model with GS  Assignment-2  2271.886904  2.091495e-02
# 19           Evaluate LR model  Assignment-2     0.041986  3.853061e-07
#
#     emissions_rate
# 3         0.000009
# 4         0.000009
# 5         0.000009
# 6         0.000009
# 7         0.000009
# 8         0.000009
# 9         0.000009
# 10        0.000009
# 11        0.000009
# 12        0.000009
# 13        0.000009
# 14        0.000009
# 15        0.000009
# 16        0.000009
# 17        0.000009
# 18        0.000009
# 19        0.000009

# %% [markdown]
# ### Normalize Data
# value minus minimum value divided by the minimum minus the maximum

# %%
emissions["emissions_rate_n"] = ((emissions["emissions_rate"] - emissions["emissions_rate"].min())/(emissions["emissions_rate"].max() - emissions["emissions_rate"].min())) 
emissions["emissions_rate_n"] = emissions["emissions_rate_n"]  - emissions["emissions_rate_n"].mean()

# %% [markdown]
# ### Visualization of Emissions Data

# %%
sns.catplot(data=emissions_total, 
            x="project_name", 
            y="emissions", 
            hue = "project_name", 
            kind="bar")
plt.yscale('log')

sns.relplot(data=emissions_total,
            x="duration", 
            y="emissions",
            hue="project_name")
plt.yscale('log')

# %%
sns.catplot(data=emissions, 
            x="project_name", 
            y="emissions_rate", 
            hue = "task_name", 
            kind="bar")

# %%
p = sns.catplot(data=emissions, 
            x="task_name", 
            y="emissions", 
            hue = "task_name", 
            kind="bar", 
            col = "project_name",
            width = .2,
            sharex = False)
p.set_xticklabels(rotation = 15)
plt.yscale('log')

# %%
sns.relplot(
    data=emissions,
    x="duration", 
    y="emissions",
    hue="task_name")
plt.yscale('log')
